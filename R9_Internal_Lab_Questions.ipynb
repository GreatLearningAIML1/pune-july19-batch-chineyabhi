# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
# IMPORT LIBRARIES AND PACKAGES
# %tensorflow_version 2.x
import tensorflow as tf
import csv
import numpy as np
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt



from keras import Model
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import Conv2D, Reshape
from keras.utils import Sequence
from keras.backend import epsilon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Change directory

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/AIML/res_9/lab')

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/AIML/res_9/lab'

# %% [markdown]
# ### Load the training data from train.csv file

# %%
data_train = pd.read_csv('train_labels.csv')

# %% [markdown]
# ### Print the shape of the train dataset

# %%
data_train.shape
# Out:
# (173, 8)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-9a7488a23b39> in <module>()
# ----> 1 import patoolib
#
# ModuleNotFoundError: No module named 'patoolib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install patool
import patoolib
patoolib.extract_archive("images_racoon.rar")
# Out:
# Collecting patool
#   Downloading https://files.pythonhosted.org/packages/43/94/52243ddff508780dd2d8110964320ab4851134a55ab102285b46e740f76a/patool-1.12-py2.py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 2.3MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12
# patool: Extracting images_racoon.rar ...
# patool: running /usr/bin/unrar x -- "/content/drive/My Drive/Colab Notebooks/AIML/res_9/lab/images_racoon.rar"
# patool:     with cwd='./Unpack_6jub7skx'
# patool: ... images_racoon.rar extracted to `images'.
# 'images'

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE=128
ALPHA = 1.0 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
TRAIN_CSV = "train_labels.csv"
with open(TRAIN_CSV, 'r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile)-1, 4))
    reader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    next(reader)
    for col, row in enumerate(reader):
               
        #for i, r in enumerate(row[1:8]): # Parse row with seven entities
        #    row[i+1] = int(r)
              
        path,  image_width, image_height,_, x0, y0, x1, y1 = row  
        path = "/content/drive/My Drive/Colab Notebooks/AIML/res_9/lab/images/" + path
        coords[col, 0] = int(x0) * IMAGE_SIZE / int(image_width) # Normalize bounding box by image size
        coords[col, 1] = int(y0) * IMAGE_SIZE / int(image_height) # Normalize bounding box by image size
        coords[col, 2] = (int(x1) - int(x0)) * IMAGE_SIZE / int(image_width) # Normalize bounding box by image size
        coords[col, 3] = (int(y1) - int(y0)) * IMAGE_SIZE / int(image_height)
        paths.append(path)

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
model = MobileNet(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, alpha=ALPHA) # Load pre-trained mobilenet
new_model = tf.keras.models.Sequential()
new_model.add(model)
 #Do not include classification (top) layer

# to freeze layers, except the new top layer, of course, which will be added below
for layer in new_model.layers:
    layer.trainable = False

# Add new top layer which is a conv layer of the same size as the previous layer so that only 4 coords of BBox can be output
#x = tf.keras.model.layers[-1].output
new_model.add(tf.keras.layers.Conv2D(4, kernel_size=4, name="coords"))
# In the line above kernel size should be 3 for img size 96, 4 for img size 128, 5 for img size 160 etc.
new_model.add(tf.keras.layers.Reshape((4,))) # These are the 4 predicted coordinates of one BBox
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_128 (Model)   (None, 4, 4, 1024)        3228864
# _________________________________________________________________
# coords (Conv2D)              (None, 1, 1, 4)           65540
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4)                 0
# =================================================================
# Total params: 3,294,404
# Trainable params: 65,540
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
gt = coords
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.compat.v1.py_func(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
new_model.compile(optimizer='Adam', loss='mse', metrics=[IoU]) # Regression loss is MSE



new_model.fit(batch_images,gt,
            epochs=30,batch_size = 32,
            verbose=1)
# Out:
# Train on 173 samples
# Epoch 1/30
# 173/173 [==============================] - 5s 31ms/sample - loss: 2854.2374 - IoU: 0.1043
# Epoch 2/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 651.1488 - IoU: 0.4364
# Epoch 3/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 645.4751 - IoU: 0.5354
# Epoch 4/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 567.2394 - IoU: 0.5275
# Epoch 5/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 345.3668 - IoU: 0.5727
# Epoch 6/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 291.1690 - IoU: 0.5687
# Epoch 7/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 243.6208 - IoU: 0.5953
# Epoch 8/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 190.0928 - IoU: 0.6655
# Epoch 9/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 164.6826 - IoU: 0.7044
# Epoch 10/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 150.0717 - IoU: 0.7096
# Epoch 11/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 127.9328 - IoU: 0.7294
# Epoch 12/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 119.5803 - IoU: 0.7411
# Epoch 13/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 115.3789 - IoU: 0.7343
# Epoch 14/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 103.0845 - IoU: 0.7515
# Epoch 15/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 94.4919 - IoU: 0.7587
# Epoch 16/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 85.9813 - IoU: 0.7779
# Epoch 17/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 81.3423 - IoU: 0.7823
# Epoch 18/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 84.4918 - IoU: 0.7694
# Epoch 19/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 72.0384 - IoU: 0.7983
# Epoch 20/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 72.5981 - IoU: 0.8042
# Epoch 21/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 63.4633 - IoU: 0.8184
# Epoch 22/30
# 173/173 [==============================] - 4s 23ms/sample - loss: 66.5171 - IoU: 0.8097
# Epoch 23/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 72.6136 - IoU: 0.7924
# Epoch 24/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 76.7660 - IoU: 0.7747
# Epoch 25/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 67.2501 - IoU: 0.7891
# Epoch 26/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 69.2200 - IoU: 0.8016
# Epoch 27/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 60.1850 - IoU: 0.8135
# Epoch 28/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 64.8892 - IoU: 0.8169
# Epoch 29/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 62.1664 - IoU: 0.8152
# Epoch 30/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 60.3438 - IoU: 0.8118

# %% [markdown]
# ### Pick a test image from the given data

# %%
import cv2
filename = '/content/drive/My Drive/Colab Notebooks/AIML/res_9/lab/images/raccoon-1.jpg'
unscaled = cv2.imread(filename) # Original image for display

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image_height, image_width, _ = unscaled.shape
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = new_model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * int(image_width) / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * int(image_height) / IMAGE_SIZE)

x1 = int((region[2]) * int(image_width) / IMAGE_SIZE)
y1 = int((region[3]) * int(image_height) / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %% [markdown]
# #### Change your present working directory

# %%
# Out:
#          Date  Temperature
# 0  1981-01-01         20.7
# 1  1981-01-02         17.9
# 2  1981-01-03         18.8
# 3  1981-01-04         14.6
# 4  1981-01-05         15.8

# %% [markdown]
# ### Load your data file

# %%
df = pd.read_csv('daily-minimum-temperatures-in-me.csv')
print(df.head())
# Out:
#          Date  Temperature
# 0  1981-01-01         20.7
# 1  1981-01-02         17.9
# 2  1981-01-03         18.8
# 3  1981-01-04         14.6
# 4  1981-01-05         15.8

# %% [markdown]
# #### Plot data

# %%
import seaborn as sns
sns.distplot(df.Temperature)

# %% [markdown]
# #### Descibe your dataframe

# %%
df.describe()
# Out:
#        Temperature
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# The distribution is very normal in nature

# %% [markdown]
# #### Check for null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
# Date           3650 non-null object
# Temperature    3650 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %% [markdown]
# #### Drop null values

# %% [markdown]
# There are no null values in the data set so this step is not needed

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %%
sns.distplot(df.Temperature, hist = True)

# %% [markdown]
# #### Check the maximum and minimum values

# %%
print("Minimum Temp = ", df.Temperature.min())
print("Max Temp = ", df.Temperature.max())
# Out:
# Minimum Temp =  0.0
# Max Temp =  26.3

# %% [markdown]
# ### Normalize the data

# %%
from sklearn.preprocessing import MinMaxScaler
#apply the sclaing to make values between 0 to 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(np.asarray(df.Temperature).reshape(-1,1))

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %%
print('Min', np.min(scaled))
print('Max', np.max(scaled))
# Out:
# Min 0.0
# Max 1.0

# %% [markdown]
# #### Look into some of the scaled values

# %%
print(scaled[:10])
# Out:
# [[0.78707224]
#  [0.68060837]
#  [0.7148289 ]
#  [0.55513308]
#  [0.60076046]
#  [0.60076046]
#  [0.60076046]
#  [0.66159696]
#  [0.82889734]
#  [0.76045627]]

# %% [markdown]
# ### Split data into Training and Testing

# %%
#Split the data into train and test based on time
train_size = int(len(scaled) * 0.70)
test_size = len(scaled - train_size)
train, test = scaled[0:train_size, :], scaled[train_size: len(scaled), :]

# %% [markdown]
# #### Print train and test size

# %%
print('train: {}\ntest: {}'.format(len(train), len(test)))
# Out:
# train: 2555
# test: 1095

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %%
def create_dataset(dataset, look_back=1):
    
    
    dataX, dataY = [], []
    
    for i in range(len(dataset)-look_back):
        
        
        a = dataset[i:(i+look_back), 0]
        
        dataX.append(a)
        
        dataY.append(dataset[i + look_back, 0])
        
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### Use function to get training and test set

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
len(X_train)
# Out:
# 2554

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %%
#samples, time_steps, features
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (2554, 1, 1)
# (1094, 1, 1)

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %%
batch_size = 1
from tensorflow.keras.models import Sequential
model = Sequential()
model.add(tf.keras.layers.LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(tf.keras.layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='sgd')

# %% [markdown]
# ### Summarize your model

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (1, 4)                    96
# _________________________________________________________________
# dense (Dense)                (1, 1)                    5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(X_train, y_train, epochs=50, batch_size=batch_size, verbose=2, shuffle=True)
# Out:
# Train on 2554 samples
# Epoch 1/50
# 2554/2554 - 4s - loss: 0.0103
# Epoch 2/50
# 2554/2554 - 4s - loss: 0.0103
# Epoch 3/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 4/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 5/50
# 2554/2554 - 5s - loss: 0.0102
# Epoch 6/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 7/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 8/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 9/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 10/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 11/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 12/50
# 2554/2554 - 5s - loss: 0.0101
# Epoch 13/50
# 2554/2554 - 5s - loss: 0.0102
# Epoch 14/50
# 2554/2554 - 5s - loss: 0.0102
# Epoch 15/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 16/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 17/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 18/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 19/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 20/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 21/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 22/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 23/50
# 2554/2554 - 4s - loss: 0.0103
# Epoch 24/50
# 2554/2554 - 5s - loss: 0.0102
# Epoch 25/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 26/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 27/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 28/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 29/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 30/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 31/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 32/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 33/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 34/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 35/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 36/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 37/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 38/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 39/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 40/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 41/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 42/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 43/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 44/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 45/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 46/50
# 2554/2554 - 4s - loss: 0.0102
# Epoch 47/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 48/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 49/50
# 2554/2554 - 4s - loss: 0.0101
# Epoch 50/50
# 2554/2554 - 4s - loss: 0.0101

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %%
import math
from sklearn.metrics import mean_squared_error

trainPredict = model.predict(X_train, batch_size=batch_size)

testPredict = model.predict(X_test, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2.73 RMSE
# Test Score: 2.60 RMSE

# %% [markdown]
# ## Plot the results

# %%
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(scaled), :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
